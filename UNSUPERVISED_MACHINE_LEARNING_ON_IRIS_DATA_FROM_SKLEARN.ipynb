# %%
from sklearn.datasets import load_iris
import pandas as pd

# Load the iris dataset
iris = load_iris()

# Create a DataFrame including features and target
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      species
# 0          0
# ...

# %%
df = df.drop(columns="species")

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# dtype: int64

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# dtype: int64

# %%
num=df.select_dtypes('number')

# %%
num.skew()
# Out:
# sepal length (cm)    0.312826
# sepal width (cm)     0.307149
# petal length (cm)   -0.263101
# petal width (cm)    -0.090076
# dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
for i in num.columns:
    plt.figure(figsize=(10,5))
    sns.distplot(df[i], color='r')
    plt.title(f"Distribution of {i}")
    plt.grid(True)
    plt.xlabel(i)
    plt.ylabel("Frequency")
    plt.show()
# Out:
# <ipython-input-117-c7aa04fc7714>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i], color='r')
# <ipython-input-117-c7aa04fc7714>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i], color='r')
# <ipython-input-117-c7aa04fc7714>:3: UserWarning:
#
# ...

# %%
for i in num.columns:
    plt.figure(figsize=(10,5))
    sns.boxplot(df[i], color='b')
    plt.title(f"Distribution of {i}")
    plt.grid(True)
    plt.xlabel(i)
    plt.ylabel("Frequency")
    plt.show()

# %% [markdown]
#  as skew ok, least outliers, so chance of error in data analysis is **less**

# %%
for i in num.columns:
    plt.figure(figsize=(10,5))
    sns.histplot(df[i], kde=True, color='r')
    plt.title(f"Distribution of {i}")
    plt.grid(True)

# %%
correlation_matrix = df.corr()
correlation_matrix
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.118129           0.873738
# sepal width (cm)           -0.118129          1.000000          -0.426028
# petal length (cm)           0.873738         -0.426028           1.000000
# petal width (cm)            0.820620         -0.362894           0.962772
#
#                    petal width (cm)
# sepal length (cm)          0.820620
# sepal width (cm)          -0.362894
# petal length (cm)          0.962772
# petal width (cm)           1.000000

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.title("correlation between features of iris")
plt.show()

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

# Standardize features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(df)

# Convert the scaled data back to a DataFrame
df_scaled = pd.DataFrame(scaled_features, columns=df.columns)

# %%
# Determine the optimal number of clusters using the Elbow Method
inertia = []
k_range = range(1, 11)  # Testing cluster numbers from 1 to 10

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(df_scaled)
    inertia.append(kmeans.inertia_)

# Plot the Elbow Method result
plt.figure(figsize=(8, 6))
plt.plot(k_range, inertia, marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal k')
plt.xticks(k_range)
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %% [markdown]
# KMEANS CLUSTERING

# %% [markdown]
# K-Means clustering is a popular unsupervised learning algorithm used to partition data into distinct clusters based on feature similarity. Applying K-Means to the Iris dataset groups flowers into clusters based on sepal and petal measurements. The number of clusters is determined using the Elbow method, which suggests k=3 as the optimal number. This division ideally corresponds to the three species of iris. Standardizing the features and applying K-Means reveal patterns in the data, which can be visualized using scatter plots

# %%
from sklearn.cluster import KMeans

# Assuming optimal number of clusters is found to be `n_clusters`
n_clusters = 3  # Replace with your optimal number of clusters

# Apply K-Means clustering
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
df['cluster'] = kmeans.fit_predict(df_scaled)
df
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# ...

# %%
sns.scatterplot(x='sepal length (cm)', y='sepal width (cm)', hue='cluster', palette='summer', data=df)
plt.title('K-Means Clustering')
plt.show()

# %%
sns.scatterplot(x='petal length (cm)', y='petal width (cm)', hue='cluster', palette='winter', data=df)
plt.title('K-Means Clustering')
plt.show()

# %%
sns.scatterplot(x='sepal length (cm)', y='petal width (cm)', hue='cluster', palette='spring', data=df)
plt.title('K-Means Clustering')
plt.show()

# %%
sns.scatterplot(x='sepal width (cm)', y='petal length (cm)', hue='cluster', palette='autumn', data=df)
plt.title('K-Means Clustering')
plt.show()

# %% [markdown]
# **Hierarchical clustering**

# %% [markdown]
# Hierarchical clustering on the Iris dataset, specifically using agglomerative hierarchical clustering, organizes flowers into a hierarchy of clusters based on sepal and petal measurements. The algorithm starts with each flower as an individual cluster and iteratively merges the closest clusters. The resulting dendrogram shows how clusters combine at various levels of similarity, helping to identify the optimal number of clusters by analyzing the tree structure.

# %%
from sklearn.cluster import AgglomerativeClustering
model = AgglomerativeClustering(n_clusters = 3, affinity='euclidean', linkage='ward')
# Assuming optimal number of clusters is found to be `n_clusters`
n_clusters = 3  # Replace with your optimal number of clusters

df['cluster'] = model.fit_predict(df_scaled)
df
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:1006: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# ...

# %%
feature_pairs = [
    ('sepal length (cm)', 'sepal width (cm)'),
    ('petal length (cm)', 'petal width (cm)'),
    ('sepal length (cm)', 'petal length (cm)'),
    ('sepal width (cm)', 'petal width (cm)')
]

# Create scatter plots for each feature pair
for x_feature, y_feature in feature_pairs:
    plt.figure(figsize=(10, 8))
    sns.scatterplot(x=x_feature, y=y_feature, hue='cluster', palette='summer', data=df)
    plt.title(f'A Clustering: {x_feature} vs {y_feature}')
    plt.show()

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
sc = linkage(df, method = 'ward')
dendrogram(sc, leaf_rotation=90)
import matplotlib.pyplot as plt
plt.xlabel('Data Points')
plt.ylabel('Euclidean Distance')
plt.tight_layout()
plt.title('Dendrogram')
plt.show()
